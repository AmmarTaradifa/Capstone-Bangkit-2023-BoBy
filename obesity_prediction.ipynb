# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
data='ObesityDataSet_raw_and_data_sinthetic.csv'

# %%
df=pd.read_csv(data)

# %%
df
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
#      FAVC  FCVC  NCP       CAEC SMOKE      CH2O  SCC       FAF       TUE  \
# 0      no   2.0  3.0  Sometimes    no  2.000000   no  0.000000  1.000000
# 1      no   3.0  3.0  Sometimes   yes  3.000000  yes  3.000000  0.000000
# 2      no   2.0  3.0  Sometimes    no  2.000000   no  2.000000  1.000000
# 3      no   3.0  3.0  Sometimes    no  2.000000   no  2.000000  0.000000
# 4      no   2.0  1.0  Sometimes    no  2.000000   no  0.000000  0.000000
# ...   ...   ...  ...        ...   ...       ...  ...       ...       ...
# 2106  yes   3.0  3.0  Sometimes    no  1.728139   no  1.676269  0.906247
# 2107  yes   3.0  3.0  Sometimes    no  2.005130   no  1.341390  0.599270
# 2108  yes   3.0  3.0  Sometimes    no  2.054193   no  1.414209  0.646288
# 2109  yes   3.0  3.0  Sometimes    no  2.852339   no  1.139107  0.586035
# 2110  yes   3.0  3.0  Sometimes    no  2.863513   no  1.026452  0.714137
#
#             CALC                 MTRANS           NObeyesdad
# 0             no  Public_Transportation        Normal_Weight
# 1      Sometimes  Public_Transportation        Normal_Weight
# 2     Frequently  Public_Transportation        Normal_Weight
# 3     Frequently                Walking   Overweight_Level_I
# 4      Sometimes  Public_Transportation  Overweight_Level_II
# ...          ...                    ...                  ...
# 2106   Sometimes  Public_Transportation     Obesity_Type_III
# 2107   Sometimes  Public_Transportation     Obesity_Type_III
# 2108   Sometimes  Public_Transportation     Obesity_Type_III
# 2109   Sometimes  Public_Transportation     Obesity_Type_III
# 2110   Sometimes  Public_Transportation     Obesity_Type_III
#
# [2111 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
#  12  FAF                             2111 non-null   float64
#  13  TUE                             2111 non-null   float64
#  14  CALC                            2111 non-null   object
#  15  MTRANS                          2111 non-null   object
#  16  NObeyesdad                      2111 non-null   object
# dtypes: float64(8), object(9)
# memory usage: 280.5+ KB

# %%
df.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# 75%       2.477420     1.666678     1.000000
# max       3.000000     3.000000     2.000000

# %%
df.shape
# Out:
# (2111, 17)

# %%
df.isnull().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
FAF=(df.FAF==0).sum()
TUE=(df.TUE==0).sum()
print("Nilia 0 pada FAF: ",FAF)
print("Nilai 0 pada TUE: ",TUE)
# Out:
# Nilia 0 pada FAF:  411
# Nilai 0 pada TUE:  557

# %%
df['FAF']=df['FAF'].replace(0,np.NaN)
df['TUE']=df['TUE'].replace(0,np.NaN)

# %%
df.shape
# Out:
# (2111, 17)

# %%
df
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
#      FAVC  FCVC  NCP       CAEC SMOKE      CH2O  SCC       FAF       TUE  \
# 0      no   2.0  3.0  Sometimes    no  2.000000   no       NaN  1.000000
# 1      no   3.0  3.0  Sometimes   yes  3.000000  yes  3.000000       NaN
# 2      no   2.0  3.0  Sometimes    no  2.000000   no  2.000000  1.000000
# 3      no   3.0  3.0  Sometimes    no  2.000000   no  2.000000       NaN
# 4      no   2.0  1.0  Sometimes    no  2.000000   no       NaN       NaN
# ...   ...   ...  ...        ...   ...       ...  ...       ...       ...
# 2106  yes   3.0  3.0  Sometimes    no  1.728139   no  1.676269  0.906247
# 2107  yes   3.0  3.0  Sometimes    no  2.005130   no  1.341390  0.599270
# 2108  yes   3.0  3.0  Sometimes    no  2.054193   no  1.414209  0.646288
# 2109  yes   3.0  3.0  Sometimes    no  2.852339   no  1.139107  0.586035
# 2110  yes   3.0  3.0  Sometimes    no  2.863513   no  1.026452  0.714137
#
#             CALC                 MTRANS           NObeyesdad
# 0             no  Public_Transportation        Normal_Weight
# 1      Sometimes  Public_Transportation        Normal_Weight
# 2     Frequently  Public_Transportation        Normal_Weight
# 3     Frequently                Walking   Overweight_Level_I
# 4      Sometimes  Public_Transportation  Overweight_Level_II
# ...          ...                    ...                  ...
# 2106   Sometimes  Public_Transportation     Obesity_Type_III
# 2107   Sometimes  Public_Transportation     Obesity_Type_III
# 2108   Sometimes  Public_Transportation     Obesity_Type_III
# 2109   Sometimes  Public_Transportation     Obesity_Type_III
# 2110   Sometimes  Public_Transportation     Obesity_Type_III
#
# [2111 rows x 17 columns]

# %%
# melihat outliers age
sns.boxplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
# melihat outliers Height
sns.boxplot(x=df['Height'])

# %%
# melihat outliers Weight
sns.boxplot(x=df['Weight'])

# %%
# melihat outliers age
sns.boxplot(x=df['FCVC'])

# %%
# melihat outliers age
sns.boxplot(x=df['NCP'])

# %%
# melihat outliers age
sns.boxplot(x=df['CH2O'])

# %%
# melihat outliers age
sns.boxplot(x=df['FAF'])

# %%
# melihat outliers age
sns.boxplot(x=df['TUE'])

# %%
#mengubah data objt menjadi int menggunakan LabelEncoder
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
#untuk NObeyesdad
NObeyesdad=encoder.fit_transform(df['NObeyesdad'])
NObeyesdad
df['NObeyesdad']=NObeyesdad

# %%
df.loc[(df['FAF'].isnull()) & (df['TUE'].isnull())] #ganti nilainya dengan mean
# Out:
#       Gender        Age    Height     Weight family_history_with_overweight  \
# 4       Male  22.000000  1.780000  89.800000                             no
# 5       Male  29.000000  1.620000  53.000000                             no
# 17    Female  29.000000  1.530000  78.000000                             no
# 18    Female  30.000000  1.710000  82.000000                            yes
# 19    Female  23.000000  1.650000  70.000000                            yes
# ...      ...        ...       ...        ...                            ...
# 1440  Female  38.542937  1.517248  79.843221                            yes
# 1487  Female  39.126310  1.562889  76.659490                            yes
# 1488  Female  37.063599  1.502609  75.279605                            yes
# 1489  Female  41.318302  1.544937  77.053948                            yes
# 1490  Female  43.726081  1.592316  77.001030                            yes
#
#      FAVC  FCVC  NCP        CAEC SMOKE      CH2O SCC  FAF  TUE       CALC  \
# 4      no   2.0  1.0   Sometimes    no  2.000000  no  NaN  NaN  Sometimes
# 5     yes   2.0  3.0   Sometimes    no  2.000000  no  NaN  NaN  Sometimes
# 17    yes   2.0  1.0   Sometimes    no  2.000000  no  NaN  NaN         no
# 18    yes   3.0  4.0  Frequently   yes  1.000000  no  NaN  NaN         no
# 19     no   2.0  1.0   Sometimes    no  2.000000  no  NaN  NaN  Sometimes
# ...   ...   ...  ...         ...   ...       ...  ..  ...  ...        ...
# 1440  yes   2.0  3.0   Sometimes    no  1.095134  no  NaN  NaN  Sometimes
# 1487  yes   2.0  3.0   Sometimes    no  1.440526  no  NaN  NaN  Sometimes
# 1488  yes   2.0  3.0   Sometimes    no  1.759803  no  NaN  NaN  Sometimes
# 1489  yes   2.0  3.0   Sometimes    no  2.090413  no  NaN  NaN  Sometimes
# 1490  yes   2.0  3.0   Sometimes    no  2.806922  no  NaN  NaN  Sometimes
#
#                      MTRANS  NObeyesdad
# 4     Public_Transportation           6
# 5                Automobile           1
# 17               Automobile           2
# 18               Automobile           6
# 19    Public_Transportation           5
# ...                     ...         ...
# 1440             Automobile           2
# 1487             Automobile           2
# 1488             Automobile           2
# 1489             Automobile           2
# 1490             Automobile           2
#
# [127 rows x 17 columns]

# %%
df.NObeyesdad.value_counts()
# Out:
# 2    351
# 4    324
# 3    297
# 5    290
# 6    290
# 1    287
# 0    272
# Name: NObeyesdad, dtype: int64

# %%
# nilai faf  dengan nilai rata-ratanya
faf_label_0=df[df['NObeyesdad']==0]['FAF'].mean()
print(faf_label_0)
faf_label_1=df[df['NObeyesdad']==1]['FAF'].mean()
print(faf_label_1)
faf_label_2=df[df['NObeyesdad']==2]['FAF'].mean()
print(faf_label_2)
faf_label_3=df[df['NObeyesdad']==3]['FAF'].mean()
print(faf_label_3)
faf_label_4=df[df['NObeyesdad']==4]['FAF'].mean()
print(faf_label_4)
faf_label_5=df[df['NObeyesdad']==5]['FAF'].mean()
print(faf_label_5)
faf_label_6=df[df['NObeyesdad']==6]['FAF'].mean()
print(faf_label_6)
# Out:
# 1.4287215252100838
# 1.7294685990338163
# 1.2827727481481483
# 1.0730168773234203
# 0.9088638523206751
# 1.2258833639999998
# 1.213279288209607

# %%
# nilai tue  dengan nilai rata-ratanya
tue_label_0=df[df['NObeyesdad']==0]['TUE'].mean()
print(tue_label_0)
tue_label_1=df[df['NObeyesdad']==1]['TUE'].mean()
print(tue_label_1)
tue_label_2=df[df['NObeyesdad']==2]['TUE'].mean()
print(tue_label_2)
tue_label_3=df[df['NObeyesdad']==3]['TUE'].mean()
print(tue_label_3)
tue_label_4=df[df['NObeyesdad']==4]['TUE'].mean()
print(tue_label_4)
tue_label_5=df[df['NObeyesdad']==5]['TUE'].mean()
print(tue_label_5)
tue_label_6=df[df['NObeyesdad']==6]['TUE'].mean()
print(tue_label_6)
# Out:
# 1.033180380090498
# 1.2278481012658229
# 1.03727819650655
# 0.7083806898148148
# 0.6064946253869969
# 0.930721329842932
# 0.9361556805555556

# %%
#mengganti nilai FAF 
df.loc[df['NObeyesdad']==0,'FAF']=df.loc[df['NObeyesdad']==0,'FAF'].fillna(faf_label_0)
df.loc[df['NObeyesdad']==1,'FAF']=df.loc[df['NObeyesdad']==1,'FAF'].fillna(faf_label_1)
df.loc[df['NObeyesdad']==2,'FAF']=df.loc[df['NObeyesdad']==2,'FAF'].fillna(faf_label_2)
df.loc[df['NObeyesdad']==3,'FAF']=df.loc[df['NObeyesdad']==3,'FAF'].fillna(faf_label_3)
df.loc[df['NObeyesdad']==4,'FAF']=df.loc[df['NObeyesdad']==4,'FAF'].fillna(faf_label_4)
df.loc[df['NObeyesdad']==5,'FAF']=df.loc[df['NObeyesdad']==5,'FAF'].fillna(faf_label_5)
df.loc[df['NObeyesdad']==6,'FAF']=df.loc[df['NObeyesdad']==6,'FAF'].fillna(faf_label_6)

# %%
#MENGGANTI NILAI tue
df.loc[df['NObeyesdad']==0,'TUE']=df.loc[df['NObeyesdad']==0,'TUE'].fillna(tue_label_0)
df.loc[df['NObeyesdad']==1,'TUE']=df.loc[df['NObeyesdad']==1,'TUE'].fillna(tue_label_1)
df.loc[df['NObeyesdad']==2,'TUE']=df.loc[df['NObeyesdad']==2,'TUE'].fillna(tue_label_2)
df.loc[df['NObeyesdad']==3,'TUE']=df.loc[df['NObeyesdad']==3,'TUE'].fillna(tue_label_3)
df.loc[df['NObeyesdad']==4,'TUE']=df.loc[df['NObeyesdad']==4,'TUE'].fillna(tue_label_4)
df.loc[df['NObeyesdad']==5,'TUE']=df.loc[df['NObeyesdad']==5,'TUE'].fillna(tue_label_5)
df.loc[df['NObeyesdad']==6,'TUE']=df.loc[df['NObeyesdad']==6,'TUE'].fillna(tue_label_6)

# %%
df.shape
# Out:
# (2111, 17)

# %%
df.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE   NObeyesdad
# count  2111.000000  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.258047     0.921738     3.015632
# std       0.612953     0.700792     0.474112     1.952090
# min       1.000000     0.000096     0.000073     0.000000
# 25%       1.584812     0.908864     0.656031     1.000000
# 50%       2.000000     1.210736     0.936156     3.000000
# 75%       2.477420     1.729469     1.037278     5.000000
# max       3.000000     3.000000     2.000000     6.000000

# %%
Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR=Q3-Q1
df=df[~((df<(Q1-1.5*IQR))|(df>(Q3+1.5*IQR))).any(axis=1)]
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_4316\2492161268.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q1=df.quantile(0.25)
# C:\Users\USER\AppData\Local\Temp\ipykernel_4316\2492161268.py:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q3=df.quantile(0.75)
# C:\Users\USER\AppData\Local\Temp\ipykernel_4316\2492161268.py:4: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df=df[~((df<(Q1-1.5*IQR))|(df>(Q3+1.5*IQR))).any(axis=1)]

# %%
df
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 5       Male  29.000000  1.620000   53.000000                             no
# 6     Female  23.000000  1.500000   55.000000                            yes
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
#      FAVC  FCVC  NCP       CAEC SMOKE      CH2O SCC       FAF       TUE  \
# 0      no   2.0  3.0  Sometimes    no  2.000000  no  1.729469  1.000000
# 2      no   2.0  3.0  Sometimes    no  2.000000  no  2.000000  1.000000
# 3      no   3.0  3.0  Sometimes    no  2.000000  no  2.000000  0.930721
# 5     yes   2.0  3.0  Sometimes    no  2.000000  no  1.729469  1.227848
# 6     yes   3.0  3.0  Sometimes    no  2.000000  no  1.000000  1.227848
# ...   ...   ...  ...        ...   ...       ...  ..       ...       ...
# 2106  yes   3.0  3.0  Sometimes    no  1.728139  no  1.676269  0.906247
# 2107  yes   3.0  3.0  Sometimes    no  2.005130  no  1.341390  0.599270
# 2108  yes   3.0  3.0  Sometimes    no  2.054193  no  1.414209  0.646288
# 2109  yes   3.0  3.0  Sometimes    no  2.852339  no  1.139107  0.586035
# 2110  yes   3.0  3.0  Sometimes    no  2.863513  no  1.026452  0.714137
#
#             CALC                 MTRANS  NObeyesdad
# 0             no  Public_Transportation           1
# 2     Frequently  Public_Transportation           1
# 3     Frequently                Walking           5
# 5      Sometimes             Automobile           1
# 6      Sometimes              Motorbike           1
# ...          ...                    ...         ...
# 2106   Sometimes  Public_Transportation           4
# 2107   Sometimes  Public_Transportation           4
# 2108   Sometimes  Public_Transportation           4
# 2109   Sometimes  Public_Transportation           4
# 2110   Sometimes  Public_Transportation           4
#
# [1174 rows x 17 columns]

# %%
#untuk gender
Gender=encoder.fit_transform(df['Gender'])
Gender
# Out:
# array([0, 1, 1, ..., 0, 0, 0])

# %%
#untuk gamily history weight
family_history_with_overweight=encoder.fit_transform(df['family_history_with_overweight'])
family_history_with_overweight
# Out:
# array([1, 1, 0, ..., 1, 1, 1])

# %%
#untuk CAEC
CAEC=encoder.fit_transform(df['CAEC'])
CAEC
# Out:
# array([2, 2, 2, ..., 2, 2, 2])

# %%
#untuk FAVC
FAVC=encoder.fit_transform(df['FAVC'])
FAVC
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
#untuk SMOKE
SMOKE=encoder.fit_transform(df['SMOKE'])
SMOKE
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
#untuk SCC
SCC=encoder.fit_transform(df['SCC'])
SCC
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
#untuk CALC
CALC=encoder.fit_transform(df['CALC'])
CALC
# Out:
# array([2, 0, 0, ..., 1, 1, 1])

# %%
#untuk MTRANS
MTRANS=encoder.fit_transform(df['MTRANS'])
MTRANS
# Out:
# array([3, 3, 4, ..., 3, 3, 3])

# %%
df['Gender']=Gender
df['family_history_with_overweight']=family_history_with_overweight
df['CAEC']=CAEC
df['FAVC']=FAVC
df['SCC']=SCC
df['SMOKE']=SMOKE
df['CALC']=CALC
df['MTRANS']=MTRANS

# %%
df
# Out:
#       Gender        Age    Height      Weight  family_history_with_overweight  \
# 0          0  21.000000  1.620000   64.000000                               1
# 2          1  23.000000  1.800000   77.000000                               1
# 3          1  27.000000  1.800000   87.000000                               0
# 5          1  29.000000  1.620000   53.000000                               0
# 6          0  23.000000  1.500000   55.000000                               1
# ...      ...        ...       ...         ...                             ...
# 2106       0  20.976842  1.710730  131.408528                               1
# 2107       0  21.982942  1.748584  133.742943                               1
# 2108       0  22.524036  1.752206  133.689352                               1
# 2109       0  24.361936  1.739450  133.346641                               1
# 2110       0  23.664709  1.738836  133.472641                               1
#
#       FAVC  FCVC  NCP  CAEC  SMOKE      CH2O  SCC       FAF       TUE  CALC  \
# 0        0   2.0  3.0     2      0  2.000000    0  1.729469  1.000000     2
# 2        0   2.0  3.0     2      0  2.000000    0  2.000000  1.000000     0
# 3        0   3.0  3.0     2      0  2.000000    0  2.000000  0.930721     0
# 5        1   2.0  3.0     2      0  2.000000    0  1.729469  1.227848     1
# 6        1   3.0  3.0     2      0  2.000000    0  1.000000  1.227848     1
# ...    ...   ...  ...   ...    ...       ...  ...       ...       ...   ...
# 2106     1   3.0  3.0     2      0  1.728139    0  1.676269  0.906247     1
# 2107     1   3.0  3.0     2      0  2.005130    0  1.341390  0.599270     1
# 2108     1   3.0  3.0     2      0  2.054193    0  1.414209  0.646288     1
# 2109     1   3.0  3.0     2      0  2.852339    0  1.139107  0.586035     1
# 2110     1   3.0  3.0     2      0  2.863513    0  1.026452  0.714137     1
#
#       MTRANS  NObeyesdad
# 0          3           1
# 2          3           1
# 3          4           5
# 5          0           1
# 6          2           1
# ...      ...         ...
# 2106       3           4
# 2107       3           4
# 2108       3           4
# 2109       3           4
# 2110       3           4
#
# [1174 rows x 17 columns]

# %%
import sklearn
from sklearn.model_selection import train_test_split

# %%
df.NObeyesdad.value_counts()
# Out:
# 4    313
# 3    178
# 2    165
# 1    148
# 6    142
# 0    116
# 5    112
# Name: NObeyesdad, dtype: int64

# %%
label=df['NObeyesdad']
features=df[['Weight','family_history_with_overweight','Height','Age','FAVC']]

# %%
X=features
y=label

# %%
#oversampling 
from collections import Counter
from imblearn import under_sampling,over_sampling
from imblearn.over_sampling import RandomOverSampler
ros=RandomOverSampler()
X_resample,y_resample=ros.fit_resample(X,y)
print(sorted(Counter(y_resample).items()),y_resample.shape)
# Out:
# [(0, 313), (1, 313), (2, 313), (3, 313), (4, 313), (5, 313), (6, 313)] (2191,)

# %%
X_resample.shape
# Out:
# (2191, 6)

# %% [markdown]
# # Frequent consumption of high caloric food (FAVC), Frequency of consumption of vegetables (FCVC), Number of main meals (NCP), Consumption of food between meals (CAEC), Consumption of water daily (CH20), and Consumption of alcohol (CALC). The attributes related with the physical condition are: Calories consumption monitoring (SCC), Physical activity frequency (FAF), Time using technology devices (TUE), Transportation used (MTRANS),

# %%
X_train, X_test, y_train,y_test=train_test_split(X_resample,y_resample,test_size=0.2, random_state=123)

# %%
'''uji=pd.DataFrame(X_test)
uji['y_test']=y_test
uji'''
# Out:
#           Weight  family_history_with_overweight  CAEC    Height        Age  \
# 1414   75.000000                               1     1  1.820000  19.000000
# 395    87.107317                               0     2  1.817641  26.787842
# 2140   78.000000                               1     2  1.699818  19.149706
# 927   111.600553                               1     2  1.643355  26.000000
# 2105   81.322970                               1     2  1.700740  23.000000
# ...          ...                             ...   ...       ...        ...
# 1709  129.852531                               1     2  1.914186  30.710511
# 956   111.539494                               1     2  1.640125  26.000000
# 707   121.253083                               1     2  1.885543  25.498751
# 1143  150.377570                               1     2  1.739457  21.131526
# 899   111.208963                               1     2  1.637725  26.000000
#
#       FAVC  y_test
# 1414     0       1
# 395      1       5
# 2140     0       6
# 927      1       4
# 2105     1       6
# ...    ...     ...
# 1709     1       3
# 956      1       4
# 707      1       3
# 1143     1       4
# 899      1       4
#
# [439 rows x 7 columns]

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix,classification_report
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)

pred = clf.predict(X_test)
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# [[57  0  0  0  0  0  0]
#  [ 0 59  0  0  0  2  0]
#  [ 0  0 68  0  0  0  0]
#  [ 0  0  0 68  0  0  0]
#  [ 0  0  0  0 74  0  0]
#  [ 0  0  0  0  0 54  0]
#  [ 0  0  0  0  0  0 57]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        57
#            1       1.00      0.97      0.98        61
#            2       1.00      1.00      1.00        68
#            3       1.00      1.00      1.00        68
#            4       1.00      1.00      1.00        74
#            5       0.96      1.00      0.98        54
#            6       1.00      1.00      1.00        57
#
#     accuracy                           1.00       439
#    macro avg       0.99      1.00      1.00       439
# weighted avg       1.00      1.00      1.00       439

# %%
#coba model lain

# %%
#coba model lain

# %%
def prediction(input_data):
    input_data_as_numpy_array=np.asarray(input_data)
    input_data_reshape=input_data_as_numpy_array.reshape(1,-1)
    input_data_reshape_std=scaler.transform(input_data_reshape)
    prediction=clf.predict(input_data_reshape_std)
    
    print(prediction)

    if (prediction==0):
        print('\nNormal_Weight')
    elif(prediction==1):
        print('\nOverweight_Level_I')
    elif(prediction==2):
        print('\nOverweight_Level_II')
    elif(prediction==3):
        print('\nObesity_Type_I')
    elif (prediction==4):
        print('\nInsufficient_Weight')
    elif(prediction==5):
        print('\nObesity_Type_II')
    else:
        print('\nObesity_Type_III')

# %%
weight=input('Masukkan berat badan anda:')
riwayat=input('Ada riwayat obesitas?: ')
height=input("Masukkan tinggi badan: ")
Age=input("Masukkan umur: ")
FAVC=input("Sering mengkonsumsi daging?: ")


prediction([weight,riwayat,CAEC,height,FAVC,Age])
# Out:
# Masukkan berat badan anda:111
# Ada riwayat obesitas?: 1
# Sering mengkonsumsi daging?:2
# Masukkan tinggi badan: 1.66
# Masukkan umur: 26
# Sering mengkonsumsi daging?: 1
# [4]
#
# Insufficient_Weight
# C:\Users\USER\.conda\envs\main\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
plt.figure(figsize=(10, 8))
correlation_matrix = df.corr().round(2)
 
# Untuk menge-print nilai di dalam kotak, gunakan parameter anot=True
sns.heatmap(data=correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5, )
plt.title("Correlation Matrix untuk Fitur Numerik ", size=20)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix untuk Fitur Numerik ')

# %%
#saving model
import pickle
filename='decision_model.pkl'
pickle.dump(clf,open(filename,'wb'))
pickle.dump(scaler,open('standar.pkl','wb'))

# %%
#loading teh save model
loaded_model=pickle.load(open('decision_model.pkl','rb'))
scaler=pickle.load(open('standar.pkl','rb'))
